# %%
import numpy as np
import tensorflow as tf

# %%
# CPU 또는 GPU 사용할지 유무를 결정하는 코드
#my_devices = tf.config.experimental.list_physical_devices(device_type='CPU')
#tf.config.experimental.set_visible_devices(devices= my_devices, device_type='CPU')

# select CPU or GPU
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '0' # Set to -1 if CPU should be used CPU = -1 , GPU = 0

gpus = tf.config.experimental.list_physical_devices('GPU')
cpus = tf.config.experimental.list_physical_devices('CPU')

if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
elif cpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        logical_cpus= tf.config.experimental.list_logical_devices('CPU')
        print(len(cpus), "Physical CPU,", len(logical_cpus), "Logical CPU")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# 1. training data
x_train = [1, 2, 3, 4]
y_train = [0, -1, -2, -3]

# 2. model
tf.model = tf.keras.Sequential()
# units == output shape, input_dim == input shape
# activation functions(시그모이드, tanh, ReLU, Leaky ReLU, softmax 등 사용)
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=1,activation='relu'))
tf.model.add(tf.keras.layers.Dense(10, activation='relu'))
tf.model.add(tf.keras.layers.Dense(1))

# 3. 손실 함수 정의 : 오차를 어떻게 계산할 것인지 
# sgd : find minimun point
# learning rate : for complex problem(real world) with normalized data : 0.001~0.0001 
sgd = tf.keras.optimizers.SGD(lr=0.1)  # SGD == standard gradient descendent, lr == learning rate
# meansquare error, 
tf.model.compile(loss='mse', optimizer=sgd)  # mse == mean_squared_error, 1/m * sig (y'-y)^2

# 4. prints summary of the model to the terminal(model information)
tf.model.summary()

# 5. fit() executes training  200번 (verbose=0, 글자 안뜨게 함, epochs 1000번 이상인 경우 적용) 
history = tf.model.fit(x_train, y_train, epochs=100)

# 6. predict() returns predicted value
y_predict = tf.model.predict(np.array([5, 4]))
print(y_predict)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5136
# Epoch 2/100
# 1/1 [==============================] - 0s 997us/step - loss: 18.7428
# Epoch 3/100
# 1/1 [==============================] - 0s 3ms/step - loss: 5.3743
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8896
# Epoch 5/100
# 1/1 [==============================] - 0s 998us/step - loss: 2.9393
# Epoch 6/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3312
# Epoch 7/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9419
# Epoch 8/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6928
# Epoch 9/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5334
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4314
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3661
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3243
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2975
# Epoch 14/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2804
# Epoch 15/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2695
# Epoch 16/100
# 1/1 [==============================] - 0s 998us/step - loss: 1.2625
# Epoch 17/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2580
# Epoch 18/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2551
# Epoch 19/100
# 1/1 [==============================] - 0s 996us/step - loss: 1.2533
# Epoch 20/100
# 1/1 [==============================] - 0s 997us/step - loss: 1.2521
# Epoch 21/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2513
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2509
# Epoch 23/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2505
# Epoch 24/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2504
# Epoch 25/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2502
# Epoch 26/100
# 1/1 [==============================] - 0s 998us/step - loss: 1.2501
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2501
# Epoch 28/100
# 1/1 [==============================] - 0s 996us/step - loss: 1.2501
# Epoch 29/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 30/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 32/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 33/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 34/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 35/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 36/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 37/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 38/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 39/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 40/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 41/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2500
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 43/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 44/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2500
# Epoch 45/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 46/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 48/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 49/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 51/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2500
# Epoch 52/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 53/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 54/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 56/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 57/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 58/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 59/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 60/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 62/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 64/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 65/100
# 1/1 [==============================] - 0s 996us/step - loss: 1.2500
# Epoch 66/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 67/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 68/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 69/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 70/100
# 1/1 [==============================] - 0s 996us/step - loss: 1.2500
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 72/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 73/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 74/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 75/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 76/100
# 1/1 [==============================] - 0s 996us/step - loss: 1.2500
# Epoch 77/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 78/100
# 1/1 [==============================] - 0s 997us/step - loss: 1.2500
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 80/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2500
# Epoch 81/100
# 1/1 [==============================] - 0s 997us/step - loss: 1.2500
# Epoch 82/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 83/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 84/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2500
# Epoch 85/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 86/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2500
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 88/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2500
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 90/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 92/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2500
# Epoch 93/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 94/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 95/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 96/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2500
# Epoch 97/100
# 1/1 [==============================] - 0s 997us/step - loss: 1.2500
# Epoch 98/100
# 1/1 [==============================] - 0s 997us/step - loss: 1.2500
# Epoch 99/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# Epoch 100/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2500
# [[-1.4999998]
#  [-1.4999998]]

# %%
import matplotlib.pyplot as plt

# %%
# 7. Graph 그리기
# %matplotlib
plt.plot(history.history['loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train','Test'], loc='upper left')
plt.show()
