# %%
# Lab 5 Logistic Regression Classifier
import tensorflow as tf
import numpy as np

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '0' # Set to -1 if CPU should be used CPU = -1 , GPU = 0

gpus = tf.config.experimental.list_physical_devices('GPU')
cpus = tf.config.experimental.list_physical_devices('CPU')

if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
elif cpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        logical_cpus= tf.config.experimental.list_logical_devices('CPU')
        print(len(cpus), "Physical CPU,", len(logical_cpus), "Logical CPU")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# file open(.csv 파일)
xy = np.loadtxt('D:/DeepLearn/TF2DeepLearningZeroToAll/data-03-diabetes.csv', delimiter=',', dtype=np.float32)
# train / test 데이터 분리, 행은 모두 사용.
# 열 : 마지막 열을 따로 분리함
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

print(x_data.shape, y_data.shape)

tf.model = tf.keras.Sequential()
# multi-variable, x_data.shape[1] == feature counts == 8 in this case
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=x_data.shape[1], activation='sigmoid'))
tf.model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01),  metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_data, y_data, epochs=100)

# accuracy!
print("Accuracy: {0}".format(history.history['accuracy'][-1]))

# predict a single data point
y_predict = tf.model.predict([[0.176471, 0.155779, 0, 0, 0, 0.052161, -0.952178, -0.733333]])
print("Predict: {0}".format(y_predict))

# evaluating model
evaluate = tf.model.evaluate(x_data, y_data)
print("loss: {0}, accuracy: {1}".format(evaluate[0], evaluate[1]))
# Out:
# (759, 8) (759, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7682 - accuracy: 0.4559
# Epoch 2/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7496 - accuracy: 0.4743
# Epoch 3/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7343 - accuracy: 0.4875
# Epoch 4/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7214 - accuracy: 0.5007
# Epoch 5/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7108 - accuracy: 0.5283
# Epoch 6/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7019 - accuracy: 0.5402
# Epoch 7/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6943 - accuracy: 0.5586
# Epoch 8/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6877 - accuracy: 0.5758
# Epoch 9/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6818 - accuracy: 0.5889
# Epoch 10/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6767 - accuracy: 0.5995
# Epoch 11/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6721 - accuracy: 0.6113
# Epoch 12/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6678 - accuracy: 0.6179
# Epoch 13/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6639 - accuracy: 0.6245
# Epoch 14/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6603 - accuracy: 0.6350
# Epoch 15/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6569 - accuracy: 0.6377
# Epoch 16/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6536 - accuracy: 0.6430
# Epoch 17/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6506 - accuracy: 0.6469
# Epoch 18/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6476 - accuracy: 0.6482
# Epoch 19/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6448 - accuracy: 0.6509
# Epoch 20/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6421 - accuracy: 0.6535
# Epoch 21/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6394 - accuracy: 0.6574
# Epoch 22/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6369 - accuracy: 0.6588
# Epoch 23/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6344 - accuracy: 0.6614
# Epoch 24/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6320 - accuracy: 0.6601
# Epoch 25/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6296 - accuracy: 0.6614
# Epoch 26/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6272 - accuracy: 0.6627
# Epoch 27/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6250 - accuracy: 0.6653
# Epoch 28/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6227 - accuracy: 0.6680
# Epoch 29/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6205 - accuracy: 0.6693
# Epoch 30/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6184 - accuracy: 0.6693
# Epoch 31/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6163 - accuracy: 0.6719
# Epoch 32/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6143 - accuracy: 0.6746
# Epoch 33/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6122 - accuracy: 0.6746
# Epoch 34/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6102 - accuracy: 0.6772
# Epoch 35/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6083 - accuracy: 0.6772
# Epoch 36/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6063 - accuracy: 0.6798
# Epoch 37/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6045 - accuracy: 0.6785
# Epoch 38/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6026 - accuracy: 0.6812
# Epoch 39/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6008 - accuracy: 0.6825
# Epoch 40/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5990 - accuracy: 0.6812
# Epoch 41/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5973 - accuracy: 0.6825
# Epoch 42/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5956 - accuracy: 0.6838
# Epoch 43/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5939 - accuracy: 0.6838
# Epoch 44/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5923 - accuracy: 0.6838
# Epoch 45/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5906 - accuracy: 0.6825
# Epoch 46/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5890 - accuracy: 0.6825
# Epoch 47/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5874 - accuracy: 0.6838
# Epoch 48/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5859 - accuracy: 0.6864
# Epoch 49/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5843 - accuracy: 0.6864
# Epoch 50/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5828 - accuracy: 0.6877
# Epoch 51/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5814 - accuracy: 0.6917
# Epoch 52/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5799 - accuracy: 0.6917
# Epoch 53/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5785 - accuracy: 0.6930
# Epoch 54/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5771 - accuracy: 0.6943
# Epoch 55/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5758 - accuracy: 0.6970
# Epoch 56/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5744 - accuracy: 0.6957
# Epoch 57/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5730 - accuracy: 0.6957
# Epoch 58/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5718 - accuracy: 0.6957
# Epoch 59/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5705 - accuracy: 0.6970
# Epoch 60/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5692 - accuracy: 0.6957
# Epoch 61/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5680 - accuracy: 0.6970
# Epoch 62/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5668 - accuracy: 0.6970
# Epoch 63/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5656 - accuracy: 0.6970
# Epoch 64/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5644 - accuracy: 0.6983
# Epoch 65/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5633 - accuracy: 0.7009
# Epoch 66/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5622 - accuracy: 0.7022
# Epoch 67/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5610 - accuracy: 0.7036
# Epoch 68/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5599 - accuracy: 0.7036
# Epoch 69/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5588 - accuracy: 0.7049
# Epoch 70/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5578 - accuracy: 0.7062
# Epoch 71/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5567 - accuracy: 0.7062
# Epoch 72/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5557 - accuracy: 0.7049
# Epoch 73/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5547 - accuracy: 0.7088
# Epoch 74/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5537 - accuracy: 0.7101
# Epoch 75/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5527 - accuracy: 0.7115
# Epoch 76/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5517 - accuracy: 0.7115
# Epoch 77/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5508 - accuracy: 0.7141
# Epoch 78/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5499 - accuracy: 0.7154
# Epoch 79/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5490 - accuracy: 0.7167
# Epoch 80/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5481 - accuracy: 0.7154
# Epoch 81/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5471 - accuracy: 0.7220
# Epoch 82/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5463 - accuracy: 0.7233
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7233
# Epoch 84/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5446 - accuracy: 0.7246
# Epoch 85/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5438 - accuracy: 0.7260
# Epoch 86/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5429 - accuracy: 0.7273
# Epoch 87/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5421 - accuracy: 0.7273
# Epoch 88/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5413 - accuracy: 0.7299
# Epoch 89/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5406 - accuracy: 0.7286
# Epoch 90/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5398 - accuracy: 0.7286
# Epoch 91/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5390 - accuracy: 0.7273
# Epoch 92/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5383 - accuracy: 0.7273
# Epoch 93/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5375 - accuracy: 0.7299
# Epoch 94/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5368 - accuracy: 0.7312
# Epoch 95/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5361 - accuracy: 0.7312
# Epoch 96/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5354 - accuracy: 0.7325
# Epoch 97/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5347 - accuracy: 0.7325
# Epoch 98/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5341 - accuracy: 0.7365
# Epoch 99/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5334 - accuracy: 0.7339
# Epoch 100/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5327 - accuracy: 0.7352
# Accuracy: 0.7351778745651245
# Predict: [[0.5939846]]
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5323 - accuracy: 0.7378
# loss: 0.5322885513305664, accuracy: 0.7378129363059998
