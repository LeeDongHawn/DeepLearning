# %%
import numpy as np
import tensorflow as tf

# %%
# CPU 또는 GPU 사용할지 유무를 결정하는 코드
#my_devices = tf.config.experimental.list_physical_devices(device_type='CPU')
#tf.config.experimental.set_visible_devices(devices= my_devices, device_type='CPU')

# select CPU or GPU
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '0' # Set to -1 if CPU should be used CPU = -1 , GPU = 0

gpus = tf.config.experimental.list_physical_devices('GPU')
cpus = tf.config.experimental.list_physical_devices('CPU')

if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
elif cpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        logical_cpus= tf.config.experimental.list_logical_devices('CPU')
        print(len(cpus), "Physical CPU,", len(logical_cpus), "Logical CPU")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# training data
x_data = [[1, 2],
          [2, 3],
          [3, 1],
          [4, 3],
          [5, 3],
          [6, 2]]
y_data = [[0],
          [0],
          [0],
          [1],
          [1],
          [1]]

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2))
# use sigmoid activation for 0~1 problem
# 값을 0~1로 조정한다. => sigmoid : binary_classification에 사용
tf.model.add(tf.keras.layers.Activation('sigmoid'))

''' 
better result with loss function == 'binary_crossentropy', try 'mse' for yourself
adding accuracy metric to get accuracy report during training
'''
tf.model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01), metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_data, y_data, epochs=100)

# Accuracy report
print("Accuracy: ", history.history['accuracy'][-1])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 3
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7334 - accuracy: 0.5000
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6540 - accuracy: 0.5000
# Epoch 3/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5747 - accuracy: 0.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4957 - accuracy: 0.5000
# Epoch 5/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.4169 - accuracy: 0.5000
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3384 - accuracy: 0.5000
# Epoch 7/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2603 - accuracy: 0.5000
# Epoch 8/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1824 - accuracy: 0.5000
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.1049 - accuracy: 0.5000
# Epoch 10/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0278 - accuracy: 0.5000
# Epoch 11/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9511 - accuracy: 0.5000
# Epoch 12/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.8749 - accuracy: 0.5000
# Epoch 13/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7991 - accuracy: 0.5000
# Epoch 14/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7238 - accuracy: 0.5000
# Epoch 15/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6491 - accuracy: 0.5000
# Epoch 16/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5749 - accuracy: 0.5000
# Epoch 17/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5014 - accuracy: 0.5000
# Epoch 18/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4286 - accuracy: 0.5000
# Epoch 19/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3566 - accuracy: 0.5000
# Epoch 20/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2853 - accuracy: 0.5000
# Epoch 21/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2149 - accuracy: 0.5000
# Epoch 22/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1454 - accuracy: 0.5000
# Epoch 23/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0769 - accuracy: 0.5000
# Epoch 24/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0095 - accuracy: 0.5000
# Epoch 25/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9432 - accuracy: 0.5000
# Epoch 26/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8782 - accuracy: 0.5000
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8144 - accuracy: 0.5000
# Epoch 28/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7521 - accuracy: 0.5000
# Epoch 29/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6912 - accuracy: 0.5000
# Epoch 30/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6320 - accuracy: 0.5000
# Epoch 31/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5744 - accuracy: 0.5000
# Epoch 32/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5186 - accuracy: 0.5000
# Epoch 33/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4646 - accuracy: 0.5000
# Epoch 34/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4126 - accuracy: 0.5000
# Epoch 35/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3626 - accuracy: 0.5000
# Epoch 36/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3148 - accuracy: 0.5000
# Epoch 37/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2690 - accuracy: 0.5000
# Epoch 38/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2256 - accuracy: 0.5000
# Epoch 39/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1843 - accuracy: 0.5000
# Epoch 40/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1453 - accuracy: 0.5000
# Epoch 41/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1087 - accuracy: 0.5000
# Epoch 42/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0743 - accuracy: 0.5000
# Epoch 43/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0421 - accuracy: 0.5000
# Epoch 44/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0121 - accuracy: 0.5000
# Epoch 45/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9843 - accuracy: 0.5000
# Epoch 46/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9585 - accuracy: 0.5000
# Epoch 47/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9348 - accuracy: 0.5000
# Epoch 48/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9129 - accuracy: 0.3333
# Epoch 49/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8928 - accuracy: 0.3333
# Epoch 50/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8743 - accuracy: 0.3333
# Epoch 51/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8575 - accuracy: 0.3333
# Epoch 52/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8421 - accuracy: 0.3333
# Epoch 53/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8281 - accuracy: 0.1667
# Epoch 54/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8153 - accuracy: 0.1667
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8036 - accuracy: 0.1667
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7930 - accuracy: 0.1667
# Epoch 57/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7833 - accuracy: 0.1667
# Epoch 58/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7745 - accuracy: 0.1667
# Epoch 59/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7665 - accuracy: 0.1667
# Epoch 60/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7591 - accuracy: 0.3333
# Epoch 61/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7525 - accuracy: 0.3333
# Epoch 62/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7464 - accuracy: 0.1667
# Epoch 63/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7408 - accuracy: 0.3333
# Epoch 64/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7357 - accuracy: 0.3333
# Epoch 65/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7310 - accuracy: 0.3333
# Epoch 66/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7267 - accuracy: 0.5000
# Epoch 67/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7227 - accuracy: 0.5000
# Epoch 68/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7190 - accuracy: 0.5000
# Epoch 69/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7156 - accuracy: 0.5000
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7125 - accuracy: 0.5000
# Epoch 71/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7095 - accuracy: 0.5000
# Epoch 72/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7068 - accuracy: 0.5000
# Epoch 73/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7042 - accuracy: 0.5000
# Epoch 74/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7018 - accuracy: 0.5000
# Epoch 75/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6996 - accuracy: 0.5000
# Epoch 76/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6975 - accuracy: 0.5000
# Epoch 77/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6955 - accuracy: 0.5000
# Epoch 78/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6936 - accuracy: 0.5000
# Epoch 79/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6918 - accuracy: 0.5000
# Epoch 80/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6901 - accuracy: 0.5000
# Epoch 81/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6885 - accuracy: 0.5000
# Epoch 82/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6869 - accuracy: 0.5000
# Epoch 83/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6854 - accuracy: 0.5000
# Epoch 84/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6840 - accuracy: 0.5000
# Epoch 85/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6826 - accuracy: 0.5000
# Epoch 86/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6812 - accuracy: 0.5000
# Epoch 87/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5000
# Epoch 88/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6787 - accuracy: 0.5000
# Epoch 89/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6775 - accuracy: 0.5000
# Epoch 90/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6763 - accuracy: 0.5000
# Epoch 91/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6751 - accuracy: 0.5000
# Epoch 92/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6740 - accuracy: 0.5000
# Epoch 93/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6729 - accuracy: 0.5000
# Epoch 94/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6718 - accuracy: 0.5000
# Epoch 95/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6708 - accuracy: 0.5000
# Epoch 96/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6697 - accuracy: 0.5000
# Epoch 97/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6687 - accuracy: 0.5000
# Epoch 98/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6677 - accuracy: 0.5000
# Epoch 99/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6667 - accuracy: 0.5000
# Epoch 100/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6658 - accuracy: 0.5000
# Accuracy:  0.5

# %%
import matplotlib.pyplot as plt

# %%
# 7. Graph 그리기
# %matplotlib
plt.plot(history.history['loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train','Test'], loc='upper left')
plt.show()
# Out:
# Using matplotlib backend: TkAgg
