# %%
import numpy as np
import tensorflow as tf

# %%
# CPU 또는 GPU 사용할지 유무를 결정하는 코드
#my_devices = tf.config.experimental.list_physical_devices(device_type='CPU')
#tf.config.experimental.set_visible_devices(devices= my_devices, device_type='CPU')

# select CPU or GPU
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '0' # Set to -1 if CPU should be used CPU = -1 , GPU = 0

gpus = tf.config.experimental.list_physical_devices('GPU')
cpus = tf.config.experimental.list_physical_devices('CPU')

if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
elif cpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        logical_cpus= tf.config.experimental.list_logical_devices('CPU')
        print(len(cpus), "Physical CPU,", len(logical_cpus), "Logical CPU")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# training data
x_data = [[73., 80., 75.],
          [93., 88., 93.],
          [89., 91., 90.],
          [96., 98., 100.],
          [73., 66., 70.]]
y_data = [[152.],
          [185.],
          [180.],
          [196.],
          [142.]]

tf.model = tf.keras.Sequential()

tf.model.add(tf.keras.layers.Dense(units=1, input_dim=3))  # input_dim=3 gives multi-variable regression
tf.model.add(tf.keras.layers.Activation('linear'))  # this line can be omitted, as linear activation is default
# advanced reading https://towardsdatascience.com/activation-functions-neural-networks-1cbd9f8d91d6

tf.model.compile(loss='mse', optimizer=tf.keras.optimizers.SGD(lr=1e-5))
tf.model.summary()
history = tf.model.fit(x_data, y_data, epochs=100)

y_predict = tf.model.predict(np.array([[72., 93., 90.]]))
print(y_predict)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 4
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - 0s 2ms/step - loss: 33691.9922
# Epoch 2/100
# 1/1 [==============================] - 0s 999us/step - loss: 10574.4561
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3328.3293
# Epoch 4/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1057.0465
# Epoch 5/100
# 1/1 [==============================] - 0s 996us/step - loss: 345.1120
# Epoch 6/100
# 1/1 [==============================] - 0s 995us/step - loss: 121.9514
# Epoch 7/100
# 1/1 [==============================] - 0s 997us/step - loss: 51.9949
# Epoch 8/100
# 1/1 [==============================] - 0s 2ms/step - loss: 30.0600
# Epoch 9/100
# 1/1 [==============================] - 0s 2ms/step - loss: 23.1773
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/step - loss: 21.0125
# Epoch 11/100
# 1/1 [==============================] - 0s 2ms/step - loss: 20.3266
# Epoch 12/100
# 1/1 [==============================] - 0s 2ms/step - loss: 20.1043
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 20.0273
# Epoch 14/100
# 1/1 [==============================] - 0s 997us/step - loss: 19.9958
# Epoch 15/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.9787
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.9660
# Epoch 17/100
# 1/1 [==============================] - 0s 996us/step - loss: 19.9547
# Epoch 18/100
# 1/1 [==============================] - 0s 998us/step - loss: 19.9438
# Epoch 19/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.9332
# Epoch 20/100
# 1/1 [==============================] - 0s 984us/step - loss: 19.9226
# Epoch 21/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.9119
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.9013
# Epoch 23/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.8907
# Epoch 24/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.8801
# Epoch 25/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.8694
# Epoch 26/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.8589
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.8483
# Epoch 28/100
# 1/1 [==============================] - 0s 998us/step - loss: 19.8377
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.8271
# Epoch 30/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.8165
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.8060
# Epoch 32/100
# 1/1 [==============================] - 0s 997us/step - loss: 19.7954
# Epoch 33/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.7848
# Epoch 34/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.7743
# Epoch 35/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.7638
# Epoch 36/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.7532
# Epoch 37/100
# 1/1 [==============================] - 0s 998us/step - loss: 19.7427
# Epoch 38/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.7322
# Epoch 39/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.7217
# Epoch 40/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.7112
# Epoch 41/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.7006
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.6901
# Epoch 43/100
# 1/1 [==============================] - 0s 1ms/step - loss: 19.6796
# Epoch 44/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.6691
# Epoch 45/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.6587
# Epoch 46/100
# 1/1 [==============================] - 0s 4ms/step - loss: 19.6482
# Epoch 47/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.6376
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.6272
# Epoch 49/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.6168
# Epoch 50/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.6063
# Epoch 51/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.5958
# Epoch 52/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.5854
# Epoch 53/100
# 1/1 [==============================] - 0s 998us/step - loss: 19.5750
# Epoch 54/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.5645
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.5541
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.5437
# Epoch 57/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.5333
# Epoch 58/100
# 1/1 [==============================] - 0s 997us/step - loss: 19.5228
# Epoch 59/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.5124
# Epoch 60/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.5020
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.4916
# Epoch 62/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.4812
# Epoch 63/100
# 1/1 [==============================] - 0s 998us/step - loss: 19.4709
# Epoch 64/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.4605
# Epoch 65/100
# 1/1 [==============================] - 0s 998us/step - loss: 19.4501
# Epoch 66/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.4398
# Epoch 67/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.4293
# Epoch 68/100
# 1/1 [==============================] - 0s 997us/step - loss: 19.4190
# Epoch 69/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.4087
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.3983
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.3880
# Epoch 72/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.3777
# Epoch 73/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.3674
# Epoch 74/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.3570
# Epoch 75/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.3467
# Epoch 76/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.3364
# Epoch 77/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.3261
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.3157
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.3055
# Epoch 80/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.2952
# Epoch 81/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.2849
# Epoch 82/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.2746
# Epoch 83/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.2644
# Epoch 84/100
# 1/1 [==============================] - 0s 997us/step - loss: 19.2541
# Epoch 85/100
# 1/1 [==============================] - 0s 998us/step - loss: 19.2438
# Epoch 86/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.2336
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.2233
# Epoch 88/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.2131
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.2028
# Epoch 90/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.1926
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.1824
# Epoch 92/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.1721
# Epoch 93/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.1619
# Epoch 94/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.1517
# Epoch 95/100
# 1/1 [==============================] - 0s 3ms/step - loss: 19.1415
# Epoch 96/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.1313
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.1211
# Epoch 98/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.1109
# Epoch 99/100
# 1/1 [==============================] - 0s 2ms/step - loss: 19.1007
# Epoch 100/100
# 1/1 [==============================] - 0s 4ms/step - loss: 19.0906
# [[150.71553]]

# %%
import matplotlib.pyplot as plt

# %%
# 7. Graph 그리기
# %matplotlib
plt.plot(history.history['loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train','Test'], loc='upper left')
plt.show()
# Out:
# Using matplotlib backend: TkAgg
